# %%
#Import libraries
import numpy as np
import pandas as pd

#Load data
df_housing = pd.read_csv('../data/Ames_Housing_Price_Data.csv', index_col=0)
#df_estate = pd.read_csv('../data/Ames_Real_Estate_Data.csv', index_col=0, low_memory=False)

# %%
pd.set_option('display.max_columns', None)
df_housing
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 1    909176150        856     126000          30       RL          NaN
# 2    905476230       1049     139500         120       RL         42.0
# 3    911128020       1001     124900          30  C (all)         60.0
# 4    535377150       1039     114000          70       RL         80.0
# 5    534177230       1665     227000          60       RL         70.0
# ..         ...        ...        ...         ...      ...          ...
# 759  903205040        952     121000          30       RL          NaN
# 760  905402060       1733     139600          20       RL          NaN
# 761  909275030       2002     145000          90       RH         82.0
# 762  907192040       1842     217500          60       RL          NaN
# 763  906223180       1911     215000          60       RL         80.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# ...

# %%
df_housing.columns
# Out:
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df_housing.drop_duplicates()
df_housing
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 1    909176150        856     126000          30       RL          NaN
# 2    905476230       1049     139500         120       RL         42.0
# 3    911128020       1001     124900          30  C (all)         60.0
# 4    535377150       1039     114000          70       RL         80.0
# 5    534177230       1665     227000          60       RL         70.0
# ..         ...        ...        ...         ...      ...          ...
# 759  903205040        952     121000          30       RL          NaN
# 760  905402060       1733     139600          20       RL          NaN
# 761  909275030       2002     145000          90       RH         82.0
# 762  907192040       1842     217500          60       RL          NaN
# 763  906223180       1911     215000          60       RL         80.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# ...

# %% [markdown]
# No exact duplicates in original df

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
